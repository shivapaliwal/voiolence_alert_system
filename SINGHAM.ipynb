# %% [markdown]
# <a href="https://colab.research.google.com/github/shivapaliwal/voiolence_alert_system/blob/main/SINGHAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip uninstall tensorflow keras tensorboard
# Out:
# Found existing installation: tensorflow 2.17.1
# Uninstalling tensorflow-2.17.1:
#   Would remove:
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.17.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
# Proceed (Y/n)? y
# y
# y
# Y
#   Successfully uninstalled tensorflow-2.17.1
# Found existing installation: keras 3.5.0
# Uninstalling keras-3.5.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/keras-3.5.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/keras/*
# Proceed (Y/n)?   Successfully uninstalled keras-3.5.0
# Found existing installation: tensorboard 2.17.1
# Uninstalling tensorboard-2.17.1:
#   Would remove:
# ...

# %%
# !pip install tensorflow==2.8.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 40.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
# ...

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-9e8c16b8a701> in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       2 print("TensorFlow version:", tf.__version__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/__init__.py in <module>
#      35
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      38
#      39 # pylint: enable=wildcard-import
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in <module>
#      27 import six
#      28
# ...

# %%
# !pip install yolov5
# !pip install opencv-python-headless

# %%
pip install telepot

# %%
pip install mtcnn

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from keras.models import load_model
from collections import deque
import matplotlib.pyplot as plt
import numpy as np
import argparse
import pickle
import cv2
import telepot
from datetime import datetime
import pytz
from PIL import Image
from PIL import ImageEnhance
import os
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN

# %%
def getTime():
  IST = pytz.timezone('Asia/Kolkata')
  timeNow = datetime.now(IST)
  return timeNow

# %%
def imgenhance():
  image1 = Image.open('savedImage.jpg')
  curr_bri = ImageEnhance.Sharpness(image1)
  new_bri = 1.3
  img_brightened = curr_bri.enhance(new_bri)
  im1 = img_brightened.save("bright.jpg")

  image2 = Image.open('bright.jpg')
  curr_col = ImageEnhance.Color(image2)
  new_col = 1.5
  img_col = curr_col.enhance(new_col)
  im2 = img_col.save("finalImage.jpg")

# %%
def draw_faces(filename, result_list):
    # load the image
    data = pyplot.imread(filename)
    # plot each face as a subplot
    for i in range(len(result_list)):
        # get coordinates
        x1, y1, width, height = result_list[i]['box']
        x2, y2 = x1 + width, y1 + height
        # define subplot
        pyplot.subplot(1, len(result_list), i+1)
        pyplot.axis('off')
        # plot face
        pyplot.imshow(data[y1:y2, x1:x2])
    # show the plot
    pyplot.savefig("faces.png")
    pyplot.show()

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import os
import time
from keras.models import load_model
from collections import deque
import torch

# Load YOLO model
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# %%
pip install opencv-python numpy tensorflow telepot

# %%
import os
os.environ['TELEGRAM_BOT_TOKEN'] = '7153869750:AAGbNI-zElAxvjyE7LSZxxZXek0t8uHakhE'
os.environ['TELEGRAM_CHAT_ID'] = '-4565287922'

# %%
from google.colab.patches import cv2_imshow

# %%
violence_model = load_model('/content/drive/MyDrive/Colab Notebooks/SIH shit/modelnew.h5')
gender_model = load_model('/content/drive/MyDrive/Colab Notebooks/SIH shit/kaggleGender.h5')

# %%
def detectViolence(video, violence_model, gender_model, limit=None):
    trueCount = 0
    imageSaved = 0
    filename = 'savedImage.jpg'
    sendAlert = 0
    location = "Kathi house , Bennett University"
    last_alert_time = 0
    alert_cooldown = 300  # 5 minutes cooldown

    # Telegram Bot setup
    bot_token = os.environ.get('TELEGRAM_BOT_TOKEN')
    chat_id = int(os.environ.get('TELEGRAM_CHAT_ID'))
    bot = telepot.Bot(bot_token)

    Q = deque(maxlen=128)
    vs = cv2.VideoCapture(video)

    if not vs.isOpened():
        print(f"Error: Unable to open video file {video}")
        return

    writer = None
    (W, H) = (None, None)

    # Face detection setup
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    total_frames = int(vs.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames <= 0:
        print(f"Error: Unable to get frame count from video {video}")
        vs.release()
        return

    for frame_count in tqdm(range(total_frames)):
        (grabbed, frame) = vs.read()
        if not grabbed:
            print(f"End of video reached at frame {frame_count}")
            break

        if frame_count % 5 != 0:  # Process every 5th frame
            continue

        if W is None or H is None:
            (H, W) = frame.shape[:2]

        output = frame.copy()

        # Face Detection
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.1, 4)

        # Initialize counters
        male_count = 0
        female_count = 0
        human_count = len(faces)

        for (x, y, w, h) in faces:
            face = frame[y:y+h, x:x+w]
            face_preprocessed = preprocess_image_for_gender(face)
            face_preprocessed = face_preprocessed / 255.0  # Normalize

            # Gender prediction
            try:
                gender_pred = gender_model.predict(np.expand_dims(face_preprocessed, axis=0))[0]
                gender = "Male" if gender_pred[0] > 0.5 else "Female"

                if gender == "Male":
                    male_count += 1
                    color = (255, 0, 0)  # Blue for male
                else:
                    female_count += 1
                    color = (0, 0, 255)  # Red for female

                cv2.rectangle(output, (x, y), (x+w, y+h), color, 2)
                cv2.putText(output, f"{gender}", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
            except Exception as e:
                print(f"Error in gender prediction: {e}")

        # Violence Detection
        violence_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        violence_frame = cv2.resize(violence_frame, (128, 128)).astype("float32") / 255

        try:
            preds = violence_model.predict(np.expand_dims(violence_frame, axis=0))[0]
            Q.append(preds)

            results = np.array(Q).mean(axis=0)
            label = (preds > 0.50)[0]

            text_color = (0, 255, 0) if not label else (0, 0, 255)
            if label:
                trueCount += 1

            # Add text for Violence, Human Count, and Gender Count
            cv2.putText(output, f"Violence: {label}", (35, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, text_color, 3)
            cv2.putText(output, f"Human Count: {human_count}", (35, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 3)
            cv2.putText(output, f"Male: {male_count}, Female: {female_count}", (35, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 3)
        except Exception as e:
            print(f"Error in violence prediction: {e}")

        if writer is None:
            fourcc = cv2.VideoWriter_fourcc(*"MJPG")
            writer = cv2.VideoWriter("recordedVideo.avi", fourcc, 30, (W, H), True)

        writer.write(output)

        # Display the output frame
        cv2_imshow(output)

        # Clear the output for the next frame
        from google.colab import output
        output.clear()

        # Alert logic
        current_time = time.time()
        if trueCount >= 10 and (current_time - last_alert_time) > alert_cooldown:
            if imageSaved == 0:
                cv2.imwrite(filename, output)
                imageSaved = 1

            alert_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            alert_message = f"VIOLENCE ALERT!!\nLOCATION: {location}\nTIME: {alert_time}\nHuman Count: {human_count}\nMale: {male_count}, Female: {female_count}"

            try:
                # Send text message
                bot.sendMessage(chat_id, alert_message)

                # Send image
                with open(filename, 'rb') as photo:
                    bot.sendPhoto(chat_id, photo, caption="Violence detected frame")

                print("Alert sent successfully")
                last_alert_time = current_time
                trueCount = 0  # Reset the count
            except Exception as e:
                print(f"Failed to send alert: {str(e)}")

        if limit and frame_count >= limit:
            print(f"Reached frame limit of {limit}")
            break

    print("[INFO] cleaning up...")
    if writer:
        writer.release()
    vs.release()

# %%
import os
import cv2
import numpy as np
from collections import deque
from keras.models import load_model
import telepot
from datetime import datetime

def detect_violence_and_gender(video, gender_model_path, limit=None):
    true_count = 0
    image_saved = False
    filename = 'savedImage.jpg'
    location = "Kathi house, Bennett University"
    send_alert = False

    # Telegram Bot setup
    bot_token = os.environ.get('TELEGRAM_BOT_TOKEN')
    chat_id = os.environ.get('TELEGRAM_CHAT_ID')

    if not bot_token or not chat_id:
        print("Error: TELEGRAM_BOT_TOKEN and TELEGRAM_CHAT_ID must be set as environment variables.")
        return

    bot = telepot.Bot(bot_token)

    try:
        print("Loading models...")
        violence_model = load_model('/content/drive/MyDrive/Colab Notebooks/SIH shit/modelnew.h5')
        gender_model = load_model('/content/drive/MyDrive/Colab Notebooks/SIH shit/kaggleGender.h5')
        # Assuming yolo_model is preloaded or defined elsewhere
        yolo_model = ...  # Load your YOLO model here

        Q = deque(maxlen=128)
        vs = cv2.VideoCapture(video)
        writer = None
        (W, H) = (None, None)

        while True:
            (grabbed, frame) = vs.read()
            if not grabbed:
                break

            if W is None or H is None:
                (H, W) = frame.shape[:2]

            output = frame.copy()

            # YOLO Detection
            yolo_results = yolo_model(frame)
            human_detections = yolo_results.xyxy[0][yolo_results.xyxy[0][:, 5] == 0]  # Class 0 is 'person'
            human_count = len(human_detections)

            # Draw YOLO detections and perform gender detection
            for detection in human_detections:
                x1, y1, x2, y2, conf, _ = detection
                cv2.rectangle(output, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)

                # Extract face region
                face = frame[int(y1):int(y2), int(x1):int(x2)]
                face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
                face_resized = cv2.resize(face_rgb, (64, 64)).astype("float32") / 255.0
                face_resized = np.expand_dims(face_resized, axis=0)

                # Predict gender
                gender_pred = gender_model.predict(face_resized)[0]
                gender_label = "Male" if gender_pred[0] > 0.5 else "Female"

                # Display gender label
                cv2.putText(output, gender_label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)

            # Violence Detection
            violence_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            violence_frame = cv2.resize(violence_frame, (128, 128)).astype("float32")
            violence_frame = violence_frame.reshape(128, 128, 3) / 255

            preds = violence_model.predict(np.expand_dims(violence_frame, axis=0))[0]
            Q.append(preds)

            results = np.array(Q).mean(axis=0)
            label = (preds > 0.50)[0]

            text_color = (0, 255, 0) if not label else (0, 0, 255)
            if label:
                true_count += 1

            # Add text for both Violence and Human Count
            cv2.putText(output, f"Violence: {label}", (35, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, text_color, 3)
            cv2.putText(output, f"Human Count: {human_count}", (35, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)

            if writer is None:
                fourcc = cv2.VideoWriter_fourcc(*"MJPG")
                writer = cv2.VideoWriter("recordedVideo.avi", fourcc, 30, (W, H), True)

            writer.write(output)
            cv2.imshow("Output", output)

            # Alert logic
            if true_count == 10:
                if not image_saved and label:
                    cv2.imwrite(filename, output)
                    image_saved = True

                if not send_alert:
                    current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    alert_message = f"VIOLENCE ALERT!!\nLOCATION: {location}\nTIME: {current_time}"

                    try:
                        # Send text message
                        bot.sendMessage(chat_id, alert_message)

                        # Send image
                        with open(filename, 'rb') as photo:
                            bot.sendPhoto(chat_id, photo, caption="Violence detected frame")

                        print("Alert sent successfully")
                    except Exception as e:
                        print(f"Failed to send alert: {str(e)}")

                    send_alert = True

            key = cv2.waitKey(1) & 0xFF
            if key == ord("q"):
                break

    except Exception as e:
        print(f"An error occurred: {str(e)}")

    finally:
        print("[INFO] Cleaning up...")
        if writer is not None:
            writer.release()
        vs.release()
        cv2.destroyAllWindows()

# Example call to the function
# detect_violence_and_gender('video.mp4', 'path_to_gender_model.h5')

# %%
V_path = "/content/drive/MyDrive/Colab Notebooks/SIH shit/videos/V_8.mp4"

# %%
detectViolence(V_path,violence_model,gender_model)

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
